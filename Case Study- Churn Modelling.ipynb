# %% [markdown]
# # CHURN Prediction

# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Data Import
#
# 1.  Extrel -donors of the organization
# 2. Payhistory: Payment history of each donor
# 3.  Communication: Communication between the donor and the organization
# 4.  Commaint: Description of the main topic code

# %%
df_extrel=pd.read_sas('C:/Users/Anirudh Mathur/Desktop/case studies/Data Prep & Churn Modeling for Fundraising/1 - Data for Churn Modeling/extrel.sas7bdat')

# %%
df_extrel.shape
# Out:
# (26689, 4)

# %%
df_extrel.dtypes
# Out:
# EXTRELNO              object
# EXRELACTCD            object
# EXTRELSTDT    datetime64[ns]
# EXRELDATEN    datetime64[ns]
# dtype: object

# %%
df_extrel.head()
# Out:
#   EXTRELNO EXRELACTCD EXTRELSTDT EXRELDATEN
# 0  0026414         CT 1995-02-02        NaT
# 1  0026419         FP 1992-03-01        NaT
# 2  0026424         FP 1992-03-01 1996-12-24
# 3  0026430         FP 1992-03-01 2006-01-31
# 4  0026430         CT 1997-03-07        NaT

# %%
df_actv_cd=pd.read_sas('C:/Users/Anirudh Mathur/Desktop/case studies/Data Prep & Churn Modeling for Fundraising/1 - Data for Churn Modeling/extrelty.sas7bdat')

# %%
df_actv_cd.head()
# Out:
#   EXRELACTCD    EXRELACTDE
# 0         FP  CommitmentDo
# 1         PS      Prospect
# 2         PF  Prosp Fundra
# 3         PP  Prosp Promot
# 4         GR       Grantor

# %%
df_actv_cd['EXRELACTCD'].value_counts().head()
# Out:
# PM    1
# PO    1
# FR    1
# GR    1
# BM    1
# Name: EXRELACTCD, dtype: int64

# %% [markdown]
# # A. DATA PREPARATION:
# ---

# %% [markdown]
# ## Setting Independent & dependent window to find active customers
#
# ***
#
# - Start of dependent window =  01 January 2006
# - End of dependent window =  31 December 2006
# - End of independent window = 03 December 2005

# %%
end_iw='2005-12-03'
st_dw='2006-01-01'

# %%
# creating group to filter Data of  active customers ( as one with - activity code = FP, - start date before end of
#IW - end date after start of DW [means he was active during IW] or missing [means still a
#donor]

group=(df_extrel['EXTRELSTDT']<end_iw ) & ((df_extrel['EXRELDATEN']>st_dw) |(df_extrel['EXRELDATEN'].isnull()))\
& (df_extrel['EXRELACTCD']=='FP')

# %%
# base table- ACtive DONORS
df_basetable=df_extrel[group]
df_basetable.head()
# Out:
#   EXTRELNO EXRELACTCD EXTRELSTDT EXRELDATEN
# 1  0026419         FP 1992-03-01        NaT
# 3  0026430         FP 1992-03-01 2006-01-31
# 5  0026431         FP 1992-03-01        NaT
# 7  0026443         FP 1992-03-01        NaT
# 8  0026444         FP 1992-03-01        NaT

# %%
print df_basetable.shape
df_basetable['startyr']=df_basetable['EXTRELSTDT'].apply(lambda x: x.year)
# Out:
# (7181, 4)
# C:\Users\Anirudh Mathur\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
count=df_basetable['startyr'].value_counts()
count.sort_index().plot('bar')

# %%
df_basetable['Churn']=np.where(df_basetable['EXRELDATEN'].isnull(),0,1)
# Out:
# C:\Users\Anirudh Mathur\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df_basetable['Churn'].value_counts()
# Out:
# 0    6675
# 1     506
# Name: Churn, dtype: int64

# %% [markdown]
# # This is the case of class imbalance.
#
# ---

# %%
# List of active donors
active_donor=df_basetable['EXTRELNO'].tolist()

# %%
df_comm=pd.read_sas('C:/Users/Anirudh Mathur/Desktop/case studies/Data Prep & Churn Modeling for Fundraising/1 - Data for Churn Modeling/communication.sas7bdat')

# %%
df_comm.head()
# Out:
#       CONTID MEDIUMCODE MNTOPCODE CLASCODE EXTRELNO CONTDIREC   CONTDATE
# 0  000405402         CI       CTS       CT  0000020         O 1994-05-09
# 1  000430904         CI       CTS       CT  0000020         O 1994-06-14
# 2  000592732         CI       CTS       CT  0000020         O 1994-10-21
# 3  000593375         CI       CTS       CT  0000020         O 1994-10-21
# 4  000618514         CI       CTS       CT  0000020         O 1994-11-28

# %%
df_comm.shape
# Out:
# (763569, 7)

# %%
# EXTRACTING Last communication Information- 
last_comm_info=df_comm.sort_values(ascending=0, by='CONTDATE').groupby('EXTRELNO').nth(0)

# %%
# Description of main topic of contact code
df_comm_tp_code=pd.read_sas('C:/Users/Anirudh Mathur/Desktop/case studies/Data Prep & Churn Modeling for Fundraising/1 - Data for Churn Modeling/commaint.sas7bdat')

# %%
df_comm_tp_code.head()
# Out:
#   MNTOPCODE                   MNTOPDESC
# 0       CAN  Cancellations/replacements
# 1       DIS            Discontinuations
# 2       MKT       Marketing - Enquiries
# 3       GEN                     General
# 4       NEW               New relations

# %%
df_comm_md_code=pd.read_sas('C:/Users/Anirudh Mathur/Desktop/case studies/Data Prep & Churn Modeling for Fundraising/1 - Data for Churn Modeling/commediu.sas7bdat')

# %%
df_comm_md_code.head()
# Out:
#   MEDIUMCODE            MEDIUMDESC
# 0         FF  Face to Face contact
# 1         FX                   Fax
# 2         TX                 Telex
# 3         EM       Electronic Mail
# 4         TE        Telephone call

# %%
df_comm_class=pd.read_sas('C:/Users/Anirudh Mathur/Desktop/case studies/Data Prep & Churn Modeling for Fundraising/1 - Data for Churn Modeling/comclas.sas7bdat')

# %%
df_comm_class
# Out:
#   CLASCODE                 CLASDESC
# 0       CT                 CTS-item
# 1       RI  Request for information
# 2       CM                Complaint
# 3       TA     Threath / Accusation
# 4       AK          Acknowledgement
# 5       RM                 Reminder
# 6       ID     Information delivery
# 7       AN                   Answer

# %% [markdown]
# ---
#
# ## Generating predictors from Payment- table

# %%
df_pay=pd.read_sas('C:/Users/Anirudh Mathur/Desktop/case studies/Data Prep & Churn Modeling for Fundraising/1 - Data for Churn Modeling/payhistory.sas7bdat')

# %%
df_pay
# Out:
#                PID      PDATE    PAMT EXTRELNO PAYTYPECD STATUS
# 0             38.0 1993-12-31    9.57  0000019         X     CO
# 1             39.0 1993-12-31   41.32  0000020         X     CO
# 2             40.0 1993-12-31   13.10  0000020         X     CO
# 3          54091.0 1994-01-01    2.02  0000020         X     CO
# 4         104480.0 1994-05-19    0.50  0000020         D     OK
# 5         128703.0 1994-06-14    0.50  0000020         D     OK
# 6         151581.0 1994-07-05    0.50  0000020         D     OK
# 7         182688.0 1994-08-15    0.50  0000020         D     OK
# 8         210468.0 1994-09-23    0.50  0000020         D     OK
# 9         235968.0 1994-10-21    0.50  0000020         D     OK
# 1205719  5079349.0 2007-01-15   27.00  0244875         E     OK
#
# [1205720 rows x 6 columns]

# %%
# Finding total payment mad eby each donor
PAMT_total=pd.pivot_table(index=['EXTRELNO'],data=df_pay,values=['PAMT'],aggfunc=sum)
PAMT_total.columns=['Total_Pamt']
PAMT_total
# Out:
#           Total_Pamt
# EXTRELNO
# 0000019         9.57
# 0000020      3176.97
# 0000035      3168.40
# 0000042      1543.03
# 0000043      4373.24
# 0000060      1333.33
# 0000072      3111.06
# 0000081      9308.71
# 0000089      3153.47
# 0000091      2288.56
# 0000093        27.21
# 0000100      3158.50
# 0000104        13.61
# 0000105      3129.90
# 0000109      3161.13
# 0000113      2846.38
# 0000114      3378.34
# 0000115      3176.47
# 0000120      1037.19
# 0000131      3122.32
# 0000133        34.76
# 0000137        84.15
# 0000148       529.00
# 0000149       134.05
# 0000156      1868.22
# 0000157       707.97
# 0000159      3156.64
# 0000165      6283.44
# 0000169      3169.40
# 0000174      3153.97
# ...              ...
# 0244460        30.00
# 0244461        30.00
# 0244468        25.00
# 0244486        25.00
# 0244514        25.00
# 0244523        25.00
# 0244530        30.00
# 0244532       300.00
# 0244537        25.00
# 0244548        25.00
# 0244569        30.00
# 0244577        30.00
# 0244585        25.00
# 0244586        25.00
# 0244589        25.00
# 0244625        25.00
# 0244631        25.00
# 0244632        30.00
# 0244638        25.00
# 0244646        25.00
# 0244660       300.00
# 0244677        25.00
# 0244678        25.00
# 0244715        25.00
# 0244728        30.00
# 0244735        25.00
# 0244827        30.00
# 0244830        25.00
# 0244853        25.00
# 0244875        27.00
#
# [16308 rows x 1 columns]

# %%
# Finding most recent date of payment
Recent_date_pay=pd.DataFrame(df_pay.groupby('EXTRELNO').apply(lambda x: x['PDATE'].max()),columns=['recent_date'])

# %%
Recent_date_pay
# Out:
#          recent_date
# EXTRELNO
# 0000019   1993-12-31
# 0000020   2007-01-17
# 0000035   2007-01-17
# 0000042   2001-01-23
# 0000043   2003-07-14
# 0000060   1999-12-07
# 0000072   2006-11-10
# 0000081   2006-12-08
# 0000089   2007-01-17
# 0000091   2003-09-15
# 0000093   1993-12-31
# 0000100   2007-01-17
# 0000104   1993-12-31
# 0000105   2006-11-10
# 0000109   2006-10-19
# 0000113   2005-09-21
# 0000114   2006-12-22
# 0000115   2007-01-17
# 0000120   1998-05-12
# 0000131   2006-11-10
# 0000133   1993-12-31
# 0000137   1993-12-31
# 0000148   1996-04-13
# 0000149   1993-12-31
# 0000156   2002-06-19
# 0000157   1997-07-03
# 0000159   2007-01-17
# 0000165   2007-01-17
# 0000169   2007-01-17
# 0000174   2007-01-17
# ...              ...
# 0244460   2007-01-10
# 0244461   2006-12-28
# 0244468   2007-01-16
# 0244486   2007-01-03
# 0244514   2007-01-17
# 0244523   2007-01-17
# 0244530   2007-01-02
# 0244532   2007-01-17
# 0244537   2007-01-09
# 0244548   2007-01-23
# 0244569   2007-01-02
# 0244577   2007-01-11
# 0244585   2007-01-09
# 0244586   2006-12-29
# 0244589   2007-01-08
# 0244625   2007-01-04
# 0244631   2007-01-05
# 0244632   2007-01-12
# 0244638   2006-12-29
# 0244646   2007-01-15
# 0244660   2007-01-16
# 0244677   2007-01-02
# 0244678   2007-01-08
# 0244715   2007-01-08
# 0244728   2007-01-02
# 0244735   2007-01-18
# 0244827   2007-01-16
# 0244830   2007-01-12
# 0244853   2007-01-18
# 0244875   2007-01-15
#
# [16308 rows x 1 columns]

# %%
# Frequency of paymenta
g=df_pay.groupby('EXTRELNO')
g.size()
frq=pd.DataFrame(g.size(),columns=['Frequency'])
frq
# Out:
#           Frequency
# EXTRELNO
# 0000019           1
# 0000020         158
# 0000035         155
# 0000042          85
# 0000043         229
# 0000060          76
# 0000072          59
# 0000081         171
# 0000089         157
# 0000091         117
# 0000093           1
# 0000100         160
# 0000104           1
# 0000105          54
# 0000109          37
# 0000113          53
# 0000114          23
# 0000115         156
# 0000120          15
# 0000131          57
# 0000133           2
# 0000137           3
# 0000148          11
# 0000149           5
# 0000156         111
# 0000157          48
# 0000159         156
# 0000165         310
# 0000169         155
# 0000174         157
# ...             ...
# 0244460           1
# 0244461           1
# 0244468           1
# 0244486           1
# 0244514           1
# 0244523           1
# 0244530           1
# 0244532           1
# 0244537           1
# 0244548           1
# 0244569           1
# 0244577           1
# 0244585           1
# 0244586           1
# 0244589           1
# 0244625           1
# 0244631           1
# 0244632           1
# 0244638           1
# 0244646           1
# 0244660           1
# 0244677           1
# 0244678           1
# 0244715           1
# 0244728           1
# 0244735           1
# 0244827           1
# 0244830           1
# 0244853           1
# 0244875           1
#
# [16308 rows x 1 columns]

# %% [markdown]
# # Getting information from communication table

# %%
# Communiation info on the last contact date
con_info_last=df_comm.sort_values(by='CONTDATE',ascending=False).groupby('EXTRELNO').nth(0)

# %%
con_info_last
# Out:
#          CLASCODE   CONTDATE CONTDIREC     CONTID MEDIUMCODE MNTOPCODE
# EXTRELNO
# 0000020        CT 2006-08-10         O  005075715         CI       CTS
# 0000035        CT 2006-10-03         O  005100553         CI       CTS
# 0000042        RI 2001-03-29         I  003271241         LE       DIS
# 0000043        ID 2004-01-23         O  004373421         LE       TAX
# 0000060        ID 2000-02-12         O  002782523         LE       TAX
# 0000072        CT 2006-10-05         O  005103306         CI       CTS
# 0000081        CT 2006-12-26         O  005155686         CI       CTS
# 0000089        CT 2006-10-31         O  005118172         CI       CTS
# 0000091        ID 2004-01-23         O  004373438         LE       TAX
# 0000100        CT 2006-07-28         O  005063408         CI       CTS
# 0000105        CT 2006-03-16         O  004979361         CI       CTS
# 0000109        CT 2007-01-19         O  005170504         CI       CTS
# 0000113        AN 2006-05-16         O  005010790         LE       DIS
# 0000114        CT 2006-11-08         O  005125617         CI       CTS
# 0000115        CT 2006-09-28         O  005097689         CI       CTS
# 0000120        RI 1999-07-22         O  002590768         FF       DIS
# 0000131        CT 2006-10-16         O  005108362         CI       CTS
# 0000148        AN 1997-04-30         O  001789980         LE       TAX
# 0000156        ID 2003-02-01         O  004019584         LE       TAX
# 0000157        ID 1998-03-24         O  002114184         LE       TAX
# 0000159        CT 2006-10-02         O  005099919         CI       CTS
# 0000165        CT 2006-11-20         O  005130953         CI       CTS
# 0000169        CT 2006-07-19         O  005057606         CI       CTS
# 0000174        CT 2006-10-20         O  005111402         CI       CTS
# 0000188        CT 2006-10-18         O  005110108         CI       CTS
# 0000199        CT 2007-01-24         O  005174957         CI       CTS
# 0000202        CT 2007-01-10         O  005164024         CI       CTS
# 0000203        CT 2006-11-06         O  005124778         CI       CTS
# 0000208        ID 2006-03-09         O  004935721         LE       TAX
# 0000210        CT 2007-01-23         O  005173093         CI       CTS
# ...           ...        ...       ...        ...        ...       ...
# 0244800        RI 2007-01-08         O  005162851         LE       INF
# 0244802        RI 2007-01-08         O  005162853         LE       INF
# 0244808        AK 2007-01-23         O  005173042         LE       VOL
# 0244827        CT 2007-01-08         O  005162947         LE       ENR
# 0244830        AK 2007-01-08         O  005162959         LE       ENR
# 0244834        CT 2007-01-08         O  005163022         LE       ENR
# 0244839        CT 2007-01-08         O  005163048         LE       ENR
# 0244851        ID 2007-01-17         O  005169397         LE       VOL
# 0244853        AK 2007-01-08         O  005163128         LE       ENR
# 0244871        AK 2007-01-08         O  005163325         LE       ENR
# 0244874        AK 2007-01-18         I  005169795         EM       FIN
# 0244875        AK 2007-01-08         O  005163354         LE       ENR
# 0244880        AK 2007-01-10         O  005165560         LE       PRO
# 0244885        CT 2007-01-09         O  005163671         LE       ENR
# 0244901        CT 2007-01-11         O  005165688         LE       ENR
# 0244909        AK 2007-01-11         O  005165681         LE       ENR
# 0244925        CT 2007-01-12         O  005167202         LE       ENR
# 0244926        RI 2007-01-16         O  005167990         FF       PRO
# 0244958        RI 2007-01-17         O  005169213         LE       INF
# 0244965        AN 2007-01-17         O  005169368         LE       INF
# 0244995        AK 2007-01-19         O  005170905         LE       ENR
# 0245006        RI 2007-01-22         O  005171235         LE       INF
# 0245012        AK 2007-01-22         O  005172346         LE       ENR
# 0245020        AN 2007-01-23         O  005172936         LE       ENR
# 0245021        AN 2007-01-23         O  005173813         LE       ENR
# 0245025        AK 2007-01-24         O  005174631         LE       PRO
# 0245029        AK 2007-01-24         O  005174110         LE       ENR
# 0245032        RI 2007-01-24         O  005174752         LE       INF
# 0245046        CT 2007-01-25         O  005175329         LE       ENR
# 0245048        CT 2007-01-25         O  005175502         LE       ENR
#
# [21932 rows x 6 columns]

# %%
# Merging Payment & Communication Information
df_f=pd.concat([PAMT_total,Recent_date_pay,frq,con_info_last],axis=1)
df_f.shape
# Out:
# (22919, 9)

# %%
df_basetable.shape
# Out:
# (7181, 6)

# %%
# Merging Active DONOR information with thier payment & communication information
df_ac_data=df_basetable.set_index('EXTRELNO').merge(df_f,left_index=True,right_index=True,how='left')

# %%
df_ac_data
# Out:
#          EXRELACTCD EXTRELSTDT EXRELDATEN  startyr  Churn  Total_Pamt  \
# EXTRELNO
# 0026419          FP 1992-03-01        NaT     1992      0     3155.05
# 0026430          FP 1992-03-01 2006-01-31     1992      1     2786.13
# 0026431          FP 1992-03-01        NaT     1992      0     3050.61
# 0026443          FP 1992-03-01        NaT     1992      0     3109.62
# 0240815          NaT        NaN       AN 2006-05-16         O  005011357
# 0240817          NaT        NaN       AN 2006-05-16         O  005011358
# 0240865   2006-12-11        9.0       CT 2006-12-01         O  005141015
# 0240867   2006-09-13        9.0       RI 2006-09-20         I  005092982
# 0240870   2006-03-08        3.0       AN 2006-04-04         O  004990223
# 0240878   2007-01-08       13.0       CT 2006-10-31         O  005117938
# 0240879          NaT        NaN       AN 2006-05-16         O  005011362
# 0240890   2007-01-17       14.0       CT 2006-11-30         O  005140708
# 0240903          NaT        NaN       AN 2006-05-16         O  005011363
# 0240910   2007-01-17       12.0       CT 2006-12-28         O  005157820
# 0240915   2007-01-17       13.0       CT 2006-12-18         O  005152852
# 0240916   2007-01-17       13.0       CT 2006-08-24         O  005081741
# 0240920   2007-01-16       14.0       CT 2006-09-07         O  005091224
# 0240936   2006-12-29       12.0       ID 2006-12-08         O  005145901
# 0240937   2007-01-17       13.0       CT 2006-12-05         O  005143189
#
#          MEDIUMCODE MNTOPCODE
# EXTRELNO
# 0026419          CI       CTS
# 0026430          LE       DIS
# 0026431          CI       CTS
# 0026443          CI       CTS
# 0026444          CI       CTS
# 0026446          CI       CTS
# 0026447          CI       CTS
# 0026470          CI       CTS
# 0026472          CI       CTS
# 0026486          CI       CTS
# 0026495          CI       CTS
# 0026498          CI       CTS
# 0026501          CI       CTS
# 0026504          CI       CTS
# 0026518          LE       CAN
# 0026521          CI       CTS
# 0026522          CI       CTS
# 0026528          CI       CTS
# 0026550          CI       CTS
# 0026551          CI       CTS
# 0026560          CI       CTS
# 0026572          CI       CTS
# 0026576          CI       CTS
# 0026600          CI       CTS
# 0026605          LE       COR
# 0026606          CI       CTS
# 0026618          CI       CTS
# 0026631          CI       CTS
# 0026632          LE       CAN
# 0026655          CI       CTS
# ...             ...       ...
# 0240685          LE       DIS
# 0240686          CI       CTS
# 0240689          EM       IRE
# 0240696          CI       CTS
# 0240698          FF       FIN
# 0240752          CI       CTS
# 0240768          CI       CTS
# 0240777          CI       CTS
# 0240778          LE       COR
# 0240799          CI       CTS
# 0240800          CI       CTS
# 0240801          CI       CTS
# 0240808          CI       CTS
# 0240809          CI       CTS
# 0240812          CI       CTS
# 0240815          LE       DIS
# 0240817          LE       DIS
# 0240865          CI       CTS
# 0240867          EM       DIS
# 0240870          LE       DIS
# 0240878          CI       CTS
# 0240879          LE       DIS
# 0240890          CI       CTS
# 0240903          LE       DIS
# 0240910          CI       CTS
# 0240915          CI       CTS
# 0240916          CI       CTS
# 0240920          CI       CTS
# 0240936          LE       ARR
# 0240937          CI       CTS
#
# [7181 rows x 14 columns]

# %%
df_ac_data.shape
# Out:
# (7181, 14)

# %%
# last day of the dump is 2/02/2007 : 
l=datetime.datetime(2007,02,02)

# %% [markdown]
# ---
#
# # List of columns with missing values

# %%
df_ac_data.columns[df_ac_data.isnull().any()]
# Out:
# Index([u'EXRELDATEN', u'Total_Pamt', u'recent_date', u'Frequency'], dtype='object')

# %% [markdown]
# ## 1.  Imputing missing values in recent_date column with mode

# %%
md_churn_date=df_ac_data[df_ac_data['Churn']==1]['recent_date'].mode()[0]

# %%
md_nt_churn_date=df_ac_data[df_ac_data['Churn']==0]['recent_date'].mode()[0]

# %%
df_ac_data.loc[((df_ac_data['Churn']==1) & (df_ac_data['recent_date'].isnull())),'recent_date']=md_churn_date
df_ac_data.loc[((df_ac_data['Churn']==0) & (df_ac_data['recent_date'].isnull())),'recent_date']=md_nt_churn_date

# %%
# Finding one mode predictor variable `RECENCY` : Time since last payment 
df_ac_data['Recency']=(map(lambda x: x,l-df_ac_data['recent_date'] ))
df_ac_data['Recency'].head()
# Out:
# EXTRELNO
# 0026419    31 days
# 0026430   472 days
# 0026431   280 days
# 0026443    16 days
# 0026444    16 days
# Name: Recency, dtype: timedelta64[ns]

# %%
# Retrieving number of days from timedelta Object
df_ac_data['Recency']=df_ac_data['Recency'].apply(lambda x: x.days)

# %%
df_ac_data['Recency'].head()
# Out:
# EXTRELNO
# 0026419     31
# 0026430    472
# 0026431    280
# 0026443     16
# 0026444     16
# Name: Recency, dtype: int64

# %%
df_ac_data
# Out:
#          EXRELACTCD EXTRELSTDT EXRELDATEN  startyr  Churn  Total_Pamt  \
# EXTRELNO
# 0026419          FP 1992-03-01        NaT     1992      0     3155.05
# 0026430          FP 1992-03-01 2006-01-31     1992      1     2786.13
# 0026431          FP 1992-03-01        NaT     1992      0     3050.61
# 0026443          FP 1992-03-01        NaT     1992      0     3109.62
# 0026444          FP 1992-03-01        NaT     1992      0     3092.47
# 0026446          FP 1992-03-01        NaT     1992      0     3667.54
# 0026447          FP 1992-03-01        NaT     1992      0     3110.13
# 0026470          FP 1992-03-01        NaT     1992      0     2949.13
# 0026472          FP 1992-03-01        NaT     1992      0     3073.64
# 0026486          FP 1992-03-01        NaT     1992      0     3133.13
# 0026495          FP 1992-03-01        NaT     1992      0     3112.80
# 0026498          FP 1992-03-01        NaT     1992      0     3133.13
# 0026501          FP 1992-03-01        NaT     1992      0     3133.13
# 0026504          FP 1992-03-01        NaT     1992      0     3134.72
# 0026518          FP 1992-03-01        NaT     1992      0     3112.80
# 0026521          FP 1992-03-01        NaT     1992      0     3163.07
# 0026522          FP 1992-03-01        NaT     1992      0     3053.27
# 0026528          FP 1992-03-01        NaT     1992      0     3163.08
# 0026550          FP 1992-03-01        NaT     1992      0     3132.11
# 0026551          FP 1992-03-01        NaT     1992      0     3115.10
# 0026560          FP 1992-03-01        NaT     1992      0     3109.12
# 0026572          FP 1992-03-01        NaT     1992      0     6176.49
# 0026576          FP 1992-03-01        NaT     1992      0     2923.20
# 0026600          FP 1992-03-01        NaT     1992      0     3040.13
# 0026605          FP 1992-03-01        NaT     1992      0     3163.07
# 0026606          FP 1992-03-01        NaT     1992      0     3033.29
# 0026618          FP 1992-03-01        NaT     1992      0     3133.11
# 0026631          FP 1992-03-01        NaT     1992      0     3133.13
# 0026632          FP 1992-03-01        NaT     1992      0     3025.00
# 0026655          FP 1992-04-01        NaT     1992      0     3053.28
# ...             ...        ...        ...      ...    ...         ...
# 0240685          FP 2005-12-01 2006-05-16     2005      1         NaN
# 0
# 0026600   2006-12-27      161.0       CT 2006-09-27         O  005096959
# 0026605   2007-01-17       53.0       AK 2007-01-08         O  005162965
# 0026606   2007-01-17       71.0       CT 2006-11-15         O  005128890
# 0026618   2007-01-17      158.0       CT 2006-08-23         O  005081344
# 0026631   2007-01-17      155.0       CT 2006-10-03         O  005100625
# 0026632   2006-12-08      118.0       RI 2007-01-17         O  005169132
# 0026655   2006-04-19       21.0       CT 2006-11-02         O  005119127
# ...              ...        ...      ...        ...       ...        ...
# 0240685   2006-12-08        NaN       AN 2006-05-16         O  005011351
# 0240686   2007-01-16       14.0       CT 2006-11-03         O  005123638
# 0240689   2007-01-02       13.0       ID 2006-12-28         I  005157514
# 0240696   2007-01-02       14.0       CT 2007-01-19         O  005170328
# 0240698   2007-01-09       11.0       ID 2006-12-14         I  005150696
# 0240752   2007-01-15       14.0       CT 2006-11-08         O  005126286
# 0240768   2006-12-08        6.0       CT 2006-12-28         O  005157863
# 0240777   2007-01-17       13.0       CT 2006-11-07         O  005125408
# 0240778   2007-01-17       14.0       AK 2006-08-16         O  005078430
# 0240799   2006-01-17        2.0       CT 2006-11-21         O  005132558
# 0240800   2007-01-17       13.0       CT 2007-01-05         O  005161391
# 0240801   2007-01-15       12.0       CT 2006-09-29         O  005099670
# 0240808   2007-01-11       14.0       CT 2006-07-20         O  005059097
# 0240809   2007-01-17       14.0       CT 2006-10-03         O  005101069
# 0240812   2007-01-17       13.0       CT 2006-10-30         O  005117460
# 0240815   2006-12-08        NaN       AN 2006-05-16         O  005011357
# 0240817   2006-12-08        NaN       AN 2006-05-16         O  005011358
# 0240865   2006-12-11        9.0       CT 2006-12-01         O  005141015
# 0240867   2006-09-13        9.0       RI 2006-09-20         I  005092982
# 0240870   2006-03-08        3.0       AN 2006-04-04         O  004990223
# 0240878   2007-01-08       13.0       CT 2006-10-31         O  005117938
# 0240879   2006-12-08        NaN       AN 2006-05-16         O  005011362
# 0240890   2007-01-17       14.0       CT 2006-11-30         O  005140708
# 0240903   2006-12-08        NaN       AN 2006-05-16         O  005011363
# 0240910   2007-01-17       12.0       CT 2006-12-28         O  005157820
# 0240915   2007-01-17       13.0       CT 2006-12-18         O  005152852
# 0240916   2007-01-17       13.0       CT 2006-08-24         O  005081741
# 0240920   2007-01-16       14.0       CT 2006-09-07         O  005091224
# 0240936   2006-12-29       12.0       ID 2006-12-08         O  005145901
# 0240937   2007-01-17       13.0       CT 2006-12-05         O  005143189
#
#          MEDIUMCODE MNTOPCODE  Recency
# EXTRELNO
# 0026419          CI       CTS       31
# 0026430          LE       DIS      472
# 0026431          CI       CTS      280
# 0026443          CI       CTS       16
# 0026444          CI       CTS       16
# 0026446          CI       CTS       16
# 0026447          CI       CTS       16
# 0026470          CI       CTS       16
# 0026472          CI       CTS      275
# 0026486          CI       CTS       16
# 0026495          CI       CTS       16
# 0026498          CI       CTS       16
# 0026501          CI       CTS       16
# 0026504          CI       CTS       22
# 0026518          LE       CAN       16
# 0026521          CI       CTS       16
# 0026522          CI       CTS      298
# 0026528          CI       CTS       16
# 0026550          CI       CTS       16
# 0026551          CI       CTS       23
# 0026560          CI       CTS       16
# 0026572          CI       CTS       28
# 0026576          CI       CTS       16
# 0026600          CI       CTS       37
# 0026605          LE       COR       16
# 0026606          CI       CTS       16
# 0026618          CI       CTS       16
# 0026631          CI       CTS       16
# 0026632          LE       CAN       56
# 0026655          CI       CTS      289
# ...             ...       ...      ...
# 0240685          LE       DIS       56
# 0240686          CI       CTS       17
# 0240689          EM       IRE       31
# 0240696          CI       CTS       31
# 0240698          FF       FIN       24
# 0240752          CI       CTS       18
# 0240768          CI       CTS       56
# 0240777          CI       CTS       16
# 0240778          LE       COR       16
# 0240799          CI       CTS      381
# 0240800          CI       CTS       16
# 0240801          CI       CTS       18
# 0240808          CI       CTS       22
# 0240809          CI       CTS       16
# 0240812          CI       CTS       16
# 0240815          LE       DIS       56
# 0240817          LE       DIS       56
# 0240865          CI       CTS       53
# 0240867          EM       DIS      142
# 0240870          LE       DIS      331
# 0240878          CI       CTS       25
# 0240879          LE       DIS       56
# 0240890          CI       CTS       16
# 0240903          LE       DIS       56
# 0240910          CI       CTS       16
# 0240915          CI       CTS       16
# 0240916          CI       CTS       16
# 0240920          CI       CTS       17
# 0240936          LE       ARR       35
# 0240937          CI       CTS       16
#
# [7181 rows x 15 columns]

# %%
# Checking for NULL
df_ac_data.columns[df_ac_data.isnull().any()]
# Out:
# Index([u'EXRELDATEN', u'Total_Pamt', u'Frequency'], dtype='object')

# %%
df_ac_data[df_ac_data['Total_Pamt'].isnull()].shape
# Out:
# (17, 15)

# %%
df_ac_data[df_ac_data['Total_Pamt'].isnull()]
# Out:
#          EXRELACTCD EXTRELSTDT EXRELDATEN  startyr  Churn  Total_Pamt  \
# EXTRELNO
# 0158182          FP 2000-02-01        NaT     2000      0         NaN
# 0217927          FP 2000-05-01 2006-01-12     2000      1         NaN
# 0225687          FP 2001-12-01        NaT     2001      0         NaN
# 0235523          FP 2004-08-01        NaT     2004      0         NaN
# 0236966          FP 2005-01-01        NaT     2005      0         NaN
# 0237647          FP 2005-01-01        NaT     2005      0         NaN
# 0239762          FP 2005-09-01 2006-01-18     2005      1         NaN
# 0239933          FP 2005-10-01 2006-03-07     2005      1         NaN
# 0240129          FP 2005-10-01 2006-03-07     2005      1         NaN
# 0240270          FP 2005-11-01 2006-03-06     2005      1         NaN
# 0240454          FP 2005-12-01 2006-02-08     2005      1         NaN
# 0240470          FP 2005-12-01 2006-05-16     2005      1         NaN
# 0240685          FP 2005-12-01 2006-05-16     2005      1         NaN
# 0240815          FP 2005-12-01 2006-05-16     2005      1         NaN
# 0240817          FP 2005-12-01 2006-05-16     2005      1         NaN
# 0240879          FP 2005-12-01 2006-05-16     2005      1         NaN
# 0240903          FP 2005-12-01 2006-05-16     2005      1         NaN
#
#          recent_date  Frequency CLASCODE   CONTDATE CONTDIREC     CONTID  \
# EXTRELNO
# 0158182   2007-01-17        NaN       ID 2003-04-18         O  004184524
# 0217927   2006-12-08        NaN       AK 2006-03-15         O  004978676
# 0225687   2007-01-17        NaN       ID 2003-09-11         O  004288013
# 0235523   2007-01-17        NaN       ID 2007-01-11         I  005165811
# 0236966   2007-01-17        NaN       ID 2005-01-05         O  004638245
# 0237647   2007-01-17        NaN       ID 2005-02-02         O  004695501
# 0239762   2006-12-08        NaN       AK 2006-03-16         O  004978981
# 0239933   2006-12-08        NaN       AN 2006-03-07         O  004933417
# 0240129   2006-12-08        NaN       AN 2006-03-07         O  004933414
# 0240270   2006-12-08        NaN       ID 2006-03-09         O  004973670
# 0240454   2006-12-08        NaN       ID 2005-11-21         I  004868876
# 0240470   2006-12-08        NaN       AN 2006-05-16         O  005010856
# 0240685   2006-12-08        NaN       AN 2006-05-16         O  005011351
# 0240815   2006-12-08        NaN       AN 2006-05-16         O  005011357
# 0240817   2006-12-08        NaN       AN 2006-05-16         O  005011358
# 0240879   2006-12-08        NaN       AN 2006-05-16         O  005011362
# 0240903   2006-12-08        NaN       AN 2006-05-16         O  005011363
#
#          MEDIUMCODE MNTOPCODE  Recency
# EXTRELNO
# 0158182          EM       REP       16
# 0217927          LE       DIS       56
# 0225687          EM       REP       16
# 0235523          MR       IRE       16
# 0236966          LE       INF       16
# 0237647          LE       INF       16
# 0239762          LE       DIS       56
# 0239933          LE       DIS       56
# 0240129          LE       DIS       56
# 0240270          LE       ARR       56
# 0240454          TE       ENR       56
# 0240470          LE       DIS       56
# 0240685          LE       DIS       56
# 0240815          LE       DIS       56
# 0240817          LE       DIS       56
# 0240879          LE       DIS       56
# 0240903          LE       DIS       56

# %%
# dropping End date & recent date
df_ac_data.drop(['EXRELDATEN','recent_date'],axis=1,inplace=True)

# %%
df_ac_data
# Out:
#          EXRELACTCD EXTRELSTDT  startyr  Churn  Total_Pamt  Frequency  \
# EXTRELNO
# 0026419          FP 1992-03-01     1992      0     3155.05       69.0
# 0026430          FP 1992-03-01     1992      1     2786.13      146.0
# 0026431          FP 1992-03-01     1992      0     3050.61       21.0
# 0026443          FP 1992-03-01     1992      0     3109.62      156.0
# 0026444          FP 1992-03-01     1992      0     3092.47      157.0
# 0026446          FP 1992-03-01     1992      0     3667.54       66.0
# 0026447          FP 1992-03-01     1992      0     3110.13      156.0
# 0026470          FP 1992-03-01     1992      0     2949.13      156.0
# 0026472          FP 1992-03-01     1992      0     3073.64       21.0
# 0026486          FP 1992-03-01     1992      0     3133.13      155.0
# 0026495          FP 1992-03-01     1992      0     3112.80      156.0
# 0026498          FP 1992-03-01     1992      0     3133.13      157.0
# 0026501          FP 1992-03-01     1992      0     3133.13      155.0
# 0026504          FP 1992-03-01     1992      0     3134.72       74.0
# 0026518          FP 1992-03-01     1992      0     3112.80      156.0
# 0026521          FP 1992-03-01     1992      0     3163.07       56.0
# 0026522          FP 1992-03-01     1992      0     3053.27       18.0
# 0026528          FP 1992-03-01     1992      0     3163.08       56.0
# 0026550          FP 1992-03-01     1992      0     3132.11      158.0
# 0026551          FP 1992-03-01     1992      0     3115.10      156.0
# 0026560          FP 1992-03-01     1992      0     3109.12      157.0
# 0026572          FP 1992-03-01     1992      0     6176.49      323.0
# 0026576          FP 1992-03-01     1992      0     2923.20      166.0
# 0026600          FP 1992-03-01     1992      0     3040.13      161.0
# 0026605          FP 1992-03-01     1992      0     3163.07       53.0
# 0026606          FP 1992-03-01     1992      0     3033.29       71.0
# 0026618          FP 1992-03-01     1992      0     3133.11      158.0
# 0026631          FP 1992-03-01     1992      0     3133.13      155.0
# 0026632          FP 1992-03-01     1992      0     3025.00      118.0
# 0026655          FP 1992-04-01     1992      0     3053.28       21.0
# ...             ...        ...      ...    ...         ...        ...
# 0240685          FP 2005-12-01     2005      1         NaN        NaN
# 0240686          FP 2005-12-01     2005      0      355.00       14.0
# 0240689          FP 2005-12-01     2005      0      301.00       13.0
# 0240696          FP 2005-12-01     2005      0      324.00       14.0
# 0240698          FP 2005-12-01     2005      0      352.00       11.0
# 0240752          FP 2005-12-01     2005      0      333.00       14.0
# 0240768          FP 2005-12-01     2005      0      345.00        6.0
# 0240777          FP 2005-12-01     2005      0      352.00       13.0
# 0240778          FP 2005-12-01     2005      0      350.00       14.0
# 0240799          FP 2005-12-01     2005      0      299.00        2.0
# 0240800          FP 2005-12-01     2005      0      490.00       13.0
# 0240801          FP 2005-12-01     2005      0      360.00       12.0
# 0240808          FP 2005-12-01     2005      0      324.00       14.0
# 0240809          FP 2005-12-01     2005      0      556.00       14.0
# 0240812          FP 2005-12-01     2005      0      324.00       13.0
# 0240815          FP 2005-12-01     2005      1         NaN        NaN
# 0240817          FP 2005-12-01     2005      1         NaN        NaN
# 0240865          FP 2005-12-01     2005      0      276.00        9.0
# 0240867          FP 2005-12-01     2005      1      230.00        9.0
# 0240870          FP 2005-12-01     2005      1       75.00        3.0
# 0240878          FP 2005-12-01     2005      0      390.00       13.0
# 0240879          FP 2005-12-01     2005      1         NaN        NaN
# 0240890          FP 2005-12-01     2005      0      324.00       14.0
# 0240903          FP 2005-12-01     2005      1         NaN        NaN
# 0240910          FP 2005-12-01     2005      0      324.00       12.0
# 0240915          FP 2005-12-01     2005      0      350.00       13.0
# 0240916          FP 2005-12-01     2005      0      350.00       13.0
# 0240920          FP 2005-12-01     2005      0      420.00       14.0
# 0240936          FP 2005-12-01     2005      0      600.00       12.0
# 0240937          FP 2005-12-01     2005      0      420.00       13.0
#
#          CLASCODE   CONTDATE CONTDIREC     CONTID MEDIUMCODE MNTOPCODE  \
# EXTRELNO
# 0026419        CT 2006-07-19         O  005057036         CI       CTS
# 0026430        AK 2006-03-16         O  004978998         LE       DIS
# 0026431        CT 2006-10-05         O  005103246         CI       CTS
# 0026443        CT 2006-12-14         O  005150482         CI       CTS
# 0026444        CT 2006-06-21         O  005034575         CI       CTS
# 0026446        CT 2006-08-28         O  005083945         CI       CTS
# 0026447        CT 2006-11-17         O  005130765         CI       CTS
# 0026470        CT 2007-01-10         O  005165099         CI       CTS
# 0026472        CT 2006-06-08         O  005026286         CI       CTS
# 0026486        CT 2006-11-30         O  005140352         CI       CTS
# 0026495        CT 2006-05-31         O  005018968         CI       CTS
# 0026498        CT 2006-07-14         O  005052883         CI       CTS
# 0026501        CT 2006-05-15         O  005009690         CI       CTS
# 0026504        CT 2006-12-12         O  005149236         CI       CTS
# 0026518        AN 2007-01-12         O  005166929         LE       CAN
# 0026521        CT 2006-11-02         O  005119912         CI       CTS
# 0026522        CT 2006-12-18         O  005152332         CI       CTS
# 0026528        CT 2007-01-05         O  005161748         CI       CTS
# 0026550        CT 2006-12-14         O  005150534         CI       CTS
# 0026551        CT 2006-09-28         O  005097851         CI       CTS
# 0026560        CT 2006-09-25         O  005095321         CI       CTS
# 0026572        CT 2006-12-08         O  005146313         CI       CTS
# 0026576        CT 2006-12-11         O  005147837         CI       CTS
# 0026600        CT 2006-09-27         O  005096959         CI       CTS
# 0026605        AK 2007-01-08         O  005162965         LE       COR
# 0026606        CT 2006-11-15         O  005128890         CI       CTS
# 0026618        CT 2006-08-23         O  005081344         CI       CTS
# 0026631        CT 2006-10-03         O  005100625         CI       CTS
# 0026632        RI 2007-01-17         O  005169132         LE       CAN
# 0026655        CT 2006-11-02         O  005119127         CI       CTS
# ...           ...        ...       ...        ...        ...       ...
# 0240685        AN 2006-05-16         O  005011351         LE       DIS
# 0240686        CT 2006-11-03         O  005123638         CI       CTS
# 0240689        ID 2006-12-28         I  005157514         EM       IRE
# 0240696        CT 2007-01-19         O  005170328         CI       CTS
# 0240698        ID 2006-12-14         I  005150696         FF       FIN
# 0240752        CT 2006-11-08         O  005126286         CI       CTS
# 0240768        CT 2006-12-28         O  005157863         CI       CTS
# 0240777        CT 2006-11-07         O  005125408         CI       CTS
# 0240778        AK 2006-08-16         O  005078430         LE       COR
# 0240799        CT 2006-11-21         O  005132558         CI       CTS
# 0240800        CT 2007-01-05         O  005161391         CI       CTS
# 0240801        CT 2006-09-29         O  005099670         CI       CTS
# 0240808        CT 2006-07-20         O  005059097         CI       CTS
# 0240809        CT 2006-10-03         O  005101069         CI       CTS
# 0240812        CT 2006-10-30         O  005117460         CI       CTS
# 0240815        AN 2006-05-16         O  005011357         LE       DIS
# 0240817        AN 2006-05-16         O  005011358         LE       DIS
# 0240865        CT 2006-12-01         O  005141015         CI       CTS
# 0240867        RI 2006-09-20         I  005092982         EM       DIS
# 0240870        AN 2006-04-04         O  004990223         LE       DIS
# 0240878        CT 2006-10-31         O  005117938         CI       CTS
# 0240879        AN 2006-05-16         O  005011362         LE       DIS
# 0240890        CT 2006-11-30         O  005140708         CI       CTS
# 0240903        AN 2006-05-16         O  005011363         LE       DIS
# 0240910        CT 2006-12-28         O  005157820         CI       CTS
# 0240915        CT 2006-12-18         O  005152852         CI       CTS
# 0240916        CT 2006-08-24         O  005081741         CI       CTS
# 0240920        CT 2006-09-07         O  005091224         CI       CTS
# 0240936        ID 2006-12-08         O  005145901         LE       ARR
# 0240937        CT 2006-12-05         O  005143189         CI       CTS
#
#           Recency
# EXTRELNO
# 0026419        31
# 0026430       472
# 0026431       280
# 0026443        16
# 0026444        16
# 0026446        16
# 0026447        16
# 0026470        16
# 0026472       275
# 0026486        16
# 0026495        16
# 0026498        16
# 0026501        16
# 0026504        22
# 0026518        16
# 0026521        16
# 0026522       298
# 0026528        16
# 0026550        16
# 0026551        23
# 0026560        16
# 0026572        28
# 0026576        16
# 0026600        37
# 0026605        16
# 0026606        16
# 0026618        16
# 0026631        16
# 0026632        56
# 0026655       289
# ...           ...
# 0240685        56
# 0240686        17
# 0240689        31
# 0240696        31
# 0240698        24
# 0240752        18
# 0240768        56
# 0240777        16
# 0240778        16
# 0240799       381
# 0240800        16
# 0240801        18
# 0240808        22
# 0240809        16
# 0240812        16
# 0240815        56
# 0240817        56
# 0240865        53
# 0240867       142
# 0240870       331
# 0240878        25
# 0240879        56
# 0240890        16
# 0240903        56
# 0240910        16
# 0240915        16
# 0240916        16
# 0240920        17
# 0240936        35
# 0240937        16
#
# [7181 rows x 13 columns]

# %% [markdown]
# # 2. Imputing Frequency & Total Payment value
#
# - Since we have two types of donors churned & still active . So we will impute accordingly

# %% [markdown]
# ## Total payment

# %% [markdown]
# #### There are 6 values where values in total payments are less than 0, so for simplicity we are deleting those rows

# %%
i=df_ac_data[df_ac_data['Total_Pamt']<0].index
df_ac_data.drop(i,axis=0,inplace=True)

# %%
# For churned donors
md_pay_churned=round(df_ac_data[df_ac_data['Churn']==1]['Total_Pamt'].median(),2)
md_pay_churned
# Out:
# 1834.52

# %%
# Still active donors
md_pay_nt_churn=round(df_ac_data[df_ac_data['Churn']==0]['Total_Pamt'].median(),2)
md_pay_nt_churn
# Out:
# 2424.81

# %%
df_ac_data.loc[((df_ac_data['Churn']==1) & (df_ac_data['Total_Pamt'].isnull())),'Total_Pamt']=md_pay_churned

# %%
df_ac_data.loc[((df_ac_data['Churn']==0) & (df_ac_data['Total_Pamt'].isnull())),'Total_Pamt']=md_pay_nt_churn

# %%
df_ac_data.Total_Pamt.isnull().any()
# Out:
# False

# %%
df_ac_data.shape
# Out:
# (7175, 13)

# %%
sns.boxplot(data=np.log(df_ac_data.Total_Pamt))

# %%
np.log(df_ac_data.Total_Pamt).hist(bins=100)
np.log(df_ac_data.Total_Pamt).describe()
# Out:
# count    7175.000000
# mean        7.569049
# std         0.618332
# min         0.693147
# 25%         7.274778
# 50%         7.768453
# 75%         8.031502
# max        10.337232
# Name: Total_Pamt, dtype: float64

# %%
df_ac_data['Total_Pamt']=np.log(df_ac_data['Total_Pamt'])

# %% [markdown]
# ## Frequency

# %%
md_frq_churned=round(df_ac_data[df_ac_data['Churn']==1]['Frequency'].median(),2)
md_frq_churned
# Out:
# 63.0

# %%
md_frq_nt_churn=round(df_ac_data[df_ac_data['Churn']==0]['Frequency'].median(),2)
md_frq_nt_churn
# Out:
# 77.0

# %%
df_ac_data.loc[((df_ac_data['Churn']==1) & (df_ac_data['Frequency'].isnull())),'Frequency']=md_frq_churned

# %%
df_ac_data.loc[((df_ac_data['Churn']==0) & (df_ac_data['Frequency'].isnull())),'Frequency']=md_frq_nt_churn

# %% [markdown]
# ---

# %%
df_ac_data
# Out:
#          EXRELACTCD EXTRELSTDT  startyr  Churn  Total_Pamt  Frequency  \
# EXTRELNO
# 0026419          FP 1992-03-01     1992      0    8.056760       69.0
# 0026430          FP 1992-03-01     1992      1    7.932409      146.0
# 0026431          FP 1992-03-01     1992      0    8.023097       21.0
# 0026443          FP 1992-03-01     1992      0    8.042256      156.0
# 0026444          FP 1992-03-01     1992      0    8.036725      157.0
# 0240916          FP 2005-12-01     2005      0    5.857933       13.0
# 0240920          FP 2005-12-01     2005      0    6.040255       14.0
# 0240936          FP 2005-12-01     2005      0    6.396930       12.0
# 0240937          FP 2005-12-01     2005      0    6.040255       13.0
#
#          CLASCODE   CONTDATE CONTDIREC     CONTID MEDIUMCODE MNTOPCODE  \
# EXTRELNO
# 0026419        CT 2006-07-19         O  005057036         CI       CTS
# 0026430        AK 2006-03-16         O  004978998         LE       DIS
# 0026431        CT 2006-10-05         O  005103246         CI       CTS
# 0026443        CT 2006-12-14         O  005150482         CI       CTS
# 0026444        CT 2006-06-21         O  005034575         CI       CTS
# 0026446        CT 2006-08-28         O  005083945         CI       CTS
# 0026447        CT 2006-11-17         O  005130765         CI       CTS
# 0026470        CT 2007-01-10         O  005165099         CI       CTS
# 0026472        CT 2006-06-08         O  005026286         CI       CTS
# 0026486        CT 2006-11-30         O  005140352         CI       CTS
# 0026495        CT 2006-05-31         O  005018968         CI       CTS
# 0026498        CT 2006-07-14         O  005052883         CI       CTS
# 0026501        CT 2006-05-15         O  005009690         CI       CTS
# 0026504        CT 2006-12-12         O  005149236         CI       CTS
# 0026518        AN 2007-01-12         O  005166929         LE       CAN
# 0026521        CT 2006-11-02         O  005119912         CI       CTS
# 0026522        CT 2006-12-18         O  005152332         CI       CTS
# 0026528        CT 2007-01-05         O  005161748         CI       CTS
# 0026550        CT 2006-12-14         O  005150534         CI       CTS
# 0026551        CT 2006-09-28         O  005097851         CI       CTS
# 0026560        CT 2006-09-25         O  005095321         CI       CTS
# 0026572        CT 2006-12-08         O  005146313         CI       CTS
# 0026576        CT 2006-12-11         O  005147837         CI       CTS
# 0026600        CT 2006-09-27         O  005096959         CI       CTS
# 0026605        AK 2007-01-08         O  005162965         LE       COR
# 0026606        CT 2006-11-15         O  005128890         CI       CTS
# 0026618        CT 2006-08-23         O  005081344         CI       CTS
# 0026631        CT 2006-10-03         O  005100625         CI       CTS
# 0026632        RI 2007-01-17         O  005169132         LE       CAN
# 0026655        CT 2006-11-02         O  005119127         CI       CTS
# ...           ...        ...       ...        ...        ...       ...
# 0240685        AN 2006-05-16         O  005011351         LE       DIS
# 0240686        CT 2006-11-03         O  005123638         CI       CTS
# 0240689        ID 2006-12-28         I  005157514         EM       IRE
# 0240696        CT 2007-01-19         O  005170328         CI       CTS
# 0240698        ID 2006-12-14         I  005150696         FF       FIN
# 0240752        CT 2006-11-08         O  005126286         CI       CTS
# 0240768        CT 2006-12-28         O  005157863         CI       CTS
# 0240777        CT 2006-11-07         O  005125408         CI       CTS
# 0240778        AK 2006-08-16         O  005078430         LE       COR
# 0240799        CT 2006-11-21         O  005132558         CI       CTS
# 0240800        CT 2007-01-05         O  005161391         CI       CTS
# 0240801        CT 2006-09-29         O  005099670         CI       CTS
# 0240808        CT 2006-07-20         O  005059097         CI       CTS
# 0240809        CT 2006-10-03         O  005101069         CI       CTS
# 0240812        CT 2006-10-30         O  005117460         CI       CTS
# 0240815        AN 2006-05-16         O  005011357         LE       DIS
# 0240817        AN 2006-05-16         O  005011358         LE       DIS
# 0240865        CT 2006-12-01         O  005141015         CI       CTS
# 0240867        RI 2006-09-20         I  005092982         EM       DIS
# 0240870        AN 2006-04-04         O  004990223         LE       DIS
# 0240878        CT 2006-10-31         O  005117938         CI       CTS
# 0240879        AN 2006-05-16         O  005011362         LE       DIS
# 0240890        CT 2006-11-30         O  005140708         CI       CTS
# 0240903        AN 2006-05-16         O  005011363         LE       DIS
# 0240910        CT 2006-12-28         O  005157820         CI       CTS
# 0240915        CT 2006-12-18         O  005152852         CI       CTS
# 0240916        CT 2006-08-24         O  005081741         CI       CTS
# 0240920        CT 2006-09-07         O  005091224         CI       CTS
# 0240936        ID 2006-12-08         O  005145901         LE       ARR
# 0240937        CT 2006-12-05         O  005143189         CI       CTS
#
#           Recency
# EXTRELNO
# 0026419        31
# 0026430       472
# 0026431       280
# 0026443        16
# 0026444        16
# 0026446        16
# 0026447        16
# 0026470        16
# 0026472       275
# 0026486        16
# 0026495        16
# 0026498        16
# 0026501        16
# 0026504        22
# 0026518        16
# 0026521        16
# 0026522       298
# 0026528        16
# 0026550        16
# 0026551        23
# 0026560        16
# 0026572        28
# 0026576        16
# 0026600        37
# 0026605        16
# 0026606        16
# 0026618        16
# 0026631        16
# 0026632        56
# 0026655       289
# ...           ...
# 0240685        56
# 0240686        17
# 0240689        31
# 0240696        31
# 0240698        24
# 0240752        18
# 0240768        56
# 0240777        16
# 0240778        16
# 0240799       381
# 0240800        16
# 0240801        18
# 0240808        22
# 0240809        16
# 0240812        16
# 0240815        56
# 0240817        56
# 0240865        53
# 0240867       142
# 0240870       331
# 0240878        25
# 0240879        56
# 0240890        16
# 0240903        56
# 0240910        16
# 0240915        16
# 0240916        16
# 0240920        17
# 0240936        35
# 0240937        16
#
# [7175 rows x 13 columns]

# %%
sns.boxplot(data=df_ac_data.Recency)

# %%
# Performing Log Transformation to mitigate effect of extreme values in Receny and Frequency Column. As shown inj above boxplot
# we have extreme values.
df_ac_data.Recency=np.log(df_ac_data['Recency'])
df_ac_data.Frequency=np.log(df_ac_data.Frequency)

# %%
# Dropping columns which are not relevant for model. 
final=df_ac_data.drop(['EXRELACTCD','EXTRELSTDT','CONTDATE','CONTID'],axis=1)

# %%
final
# Out:
#           startyr  Churn  Total_Pamt  Frequency CLASCODE CONTDIREC MEDIUMCODE  \
# EXTRELNO
# 0026419      1992      0    8.056760   4.234107       CT         O         CI
# 0026430      1992      1    7.932409   4.983607       AK         O         LE
# 0026431      1992      0    8.023097   3.044522       CT         O         CI
# 0026443      1992      0    8.042256   5.049856       CT         O         CI
# 0026444      1992      0    8.036725   5.056246       CT         O         CI
# 0026446      1992      0    8.207276   4.189655       CT         O         CI
# 0026447      1992      0    8.042420   5.049856       CT         O         CI
# 0026470      1992      0    7.989265   5.049856       CT         O         CI
# 0026472      1992      0    8.030618   3.044522       CT         O         CI
# 0026486      1992      0    8.049788   5.043425       CT         O         CI
# 0026495      1992      0    8.043278   5.049856       CT         O         CI
# 0026498      1992      0    8.049788   5.056246       CT         O         CI
# 0026501      1992      0    8.049788   5.043425       CT         O         CI
# 0026504      1992      0    8.050295   4.304065       CT         O         CI
# 0026518      1992      0    8.043278   5.049856       AN         O         LE
# 0026521      1992      0    8.059298   4.025352       CT         O         CI
# 0026522      1992      0    8.023968   2.890372       CT         O         CI
# 0026528      1992      0    8.059302   4.025352       CT         O         CI
# 0026550      1992      0    8.049462   5.062595       CT         O         CI
# 0026551      1992      0    8.044017   5.049856       CT         O         CI
# 0026560      1992      0    8.042095   5.056246       CT         O         CI
# 0026572      1992      0    8.728505   5.777652       CT         O         CI
# 0026576      1992      0    7.980434   5.111988       CT         O         CI
# 0026600      1992      0    8.019656   5.081404       CT         O         CI
# 0026605      1992      0    8.059298   3.970292       AK         O         LE
# 0026606      1992      0    8.017403   4.262680       CT         O         CI
# 0026618      1992      0    8.049781   5.062595       CT         O         CI
# 0026631      1992      0    8.049788   5.043425       CT         O         CI
# 0026632      1992      0    8.014666   4.770685       RI         O         LE
# 0026655      1992      0    8.023972   3.044522       CT         O         CI
# ...           ...    ...         ...        ...      ...       ...        ...
# 0240685      2005      1    7.514538   4.143135       AN         O         LE
# 0240686      2005      0    5.872118   2.639057       CT         O         CI
# 0240689      2005      0    5.707110   2.564949       ID         I         EM
# 0240696      2005      0    5.780744   2.639057       CT         O         CI
# 0240698      2005      0    5.863631   2.397895       ID         I         FF
# 0240752      2005      0    5.808142   2.639057       CT         O         CI
# 0240768      2005      0    5.843544   1.791759       CT         O         CI
# 0240777      2005      0    5.863631   2.564949       CT         O         CI
# 0240778      2005      0    5.857933   2.639057       AK         O         LE
# 0240799      2005      0    5.700444   0.693147       CT         O         CI
# 0240800      2005      0    6.194405   2.564949       CT         O         CI
# 0240801      2005      0    5.886104   2.484907       CT         O         CI
# 0240808      2005      0    5.780744   2.639057       CT         O         CI
# 0240809      2005      0    6.320768   2.639057       CT         O         CI
# 0240812      2005      0    5.780744   2.564949       CT         O         CI
# 0240815      2005      1    7.514538   4.143135       AN         O         LE
# 0240817      2005      1    7.514538   4.143135       AN         O         LE
# 0240865      2005      0    5.620401   2.197225       CT         O         CI
# 0240867      2005      1    5.438079   2.197225       RI         I         EM
# 0240870      2005      1    4.317488   1.098612       AN         O         LE
# 0240878      2005      0    5.966147   2.564949       CT         O         CI
# 0240879      2005      1    7.514538   4.143135       AN         O         LE
# 0240890      2005      0    5.780744   2.639057       CT         O         CI
# 0240903      2005      1    7.514538   4.143135       AN         O         LE
# 0240910      2005      0    5.780744   2.484907       CT         O         CI
# 0240915      2005      0    5.857933   2.564949       CT         O         CI
# 0240916      2005      0    5.857933   2.564949       CT         O         CI
# 0240920      2005      0    6.040255   2.639057       CT         O         CI
# 0240936      2005      0    6.396930   2.484907       ID         O         LE
# 0240937      2005      0    6.040255   2.564949       CT         O         CI
#
#          MNTOPCODE   Recency
# EXTRELNO
# 0026419        CTS  3.433987
# 0026430        DIS  6.156979
# 0026431        CTS  5.634790
# 0026443        CTS  2.772589
# 0026444        CTS  2.772589
# 0026446        CTS  2.772589
# 0026447        CTS  2.772589
# 0026470        CTS  2.772589
# 0026472        CTS  5.616771
# 0026486        CTS  2.772589
# 0026495        CTS  2.772589
# 0026498        CTS  2.772589
# 0026501        CTS  2.772589
# 0026504        CTS  3.091042
# 0026518        CAN  2.772589
# 0026521        CTS  2.772589
# 0026522        CTS  5.697093
# 0026528        CTS  2.772589
# 0026550        CTS  2.772589
# 0026551        CTS  3.135494
# 0026560        CTS  2.772589
# 0026572        CTS  3.332205
# 0026576        CTS  2.772589
# 0026600        CTS  3.610918
# 0026605        COR  2.772589
# 0026606        CTS  2.772589
# 0026618        CTS  2.772589
# 0026631        CTS  2.772589
# 0026632        CAN  4.025352
# 0026655        CTS  5.666427
# ...            ...       ...
# 0240685        DIS  4.025352
# 0240686        CTS  2.833213
# 0240689        IRE  3.433987
# 0240696        CTS  3.433987
# 0240698        FIN  3.178054
# 0240752        CTS  2.890372
# 0240768        CTS  4.025352
# 0240777        CTS  2.772589
# 0240778        COR  2.772589
# 0240799        CTS  5.942799
# 0240800        CTS  2.772589
# 0240801        CTS  2.890372
# 0240808        CTS  3.091042
# 0240809        CTS  2.772589
# 0240812        CTS  2.772589
# 0240815        DIS  4.025352
# 0240817        DIS  4.025352
# 0240865        CTS  3.970292
# 0240867        DIS  4.955827
# 0240870        DIS  5.802118
# 0240878        CTS  3.218876
# 0240879        DIS  4.025352
# 0240890        CTS  2.772589
# 0240903        DIS  4.025352
# 0240910        CTS  2.772589
# 0240915        CTS  2.772589
# 0240916        CTS  2.772589
# 0240920        CTS  2.833213
# 0240936        ARR  3.555348
# 0240937        CTS  2.772589
#
# [7175 rows x 9 columns]

# %%
final.dtypes
# Out:
# startyr         int64
# Churn           int32
# Total_Pamt    float64
# Frequency     float64
# CLASCODE       object
# CONTDIREC      object
# MEDIUMCODE     object
# MNTOPCODE      object
# Recency       float64
# dtype: object

# %% [markdown]
# # Creating dummies for categorical data

# %%
final_dumm=pd.get_dummies(final)

# %%
final_dumm.shape
# Out:
# (7175, 42)

# %%
final_dumm.head()
# Out:
#           startyr  Churn  Total_Pamt  Frequency   Recency  CLASCODE_AK  \
# EXTRELNO
# 0026419      1992      0    8.056760   4.234107  3.433987            0
# 0026430      1992      1    7.932409   4.983607  6.156979            1
# 0026431      1992      0    8.023097   3.044522  5.634790            0
# 0026443      1992      0    8.042256   5.049856  2.772589            0
# 0026444      1992      0    8.036725   5.056246  2.772589            0
#
#           CLASCODE_AN  CLASCODE_CM  CLASCODE_CT  CLASCODE_ID      ...        \
# EXTRELNO                                                          ...
# 0026419             0            0            1            0      ...
# 0026430             0            0            0            0      ...
# 0026431             0            0            1            0      ...
# 0026443             0            0            1            0      ...
# 0026444             0            0            1            0      ...
#
#           MNTOPCODE_FIN  MNTOPCODE_IFF  MNTOPCODE_INF  MNTOPCODE_IRE  \
# EXTRELNO
# 0026419               0              0              0              0
# 0026430               0              0              0              0
# 0026431               0              0              0              0
# 0026443               0              0              0              0
# 0026444               0              0              0              0
#
#           MNTOPCODE_PRO  MNTOPCODE_REP  MNTOPCODE_TAX  MNTOPCODE_VIS  \
# EXTRELNO
# 0026419               0              0              0              0
# 0026430               0              0              0              0
# 0026431               0              0              0              0
# 0026443               0              0              0              0
# 0026444               0              0              0              0
#
#           MNTOPCODE_VOL  MNTOPCODE_WEB
# EXTRELNO
# 0026419               0              0
# 0026430               0              0
# 0026431               0              0
# 0026443               0              0
# 0026444               0              0
#
# [5 rows x 42 columns]

# %%
# Seprating Train , Validate & test samples
f_tr=final_dumm[final_dumm['startyr']<2003]
f_vl=final_dumm[final_dumm['startyr']==2004]
f_test=final_dumm[final_dumm['startyr']>2004]

# %%
f_tr_target=f_tr['Churn']
f_v1_target=f_vl['Churn']
f_test_target=f_test['Churn']

# %%
f_tr.drop(['Churn','startyr'],axis=1,inplace=True)
f_vl.drop(['Churn','startyr'],axis=1,inplace=True)
f_test.drop(['Churn','startyr'],axis=1,inplace=True)
# Out:
# C:\Users\Anirudh Mathur\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\Anirudh Mathur\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\Anirudh Mathur\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
f_tr
# Out:
#           Total_Pamt  Frequency   Recency  CLASCODE_AK  CLASCODE_AN  \
# EXTRELNO
# 0026419     8.056760   4.234107  3.433987            0            0
# 0026430     7.932409   4.983607  6.156979            1            0
# 0026431     8.023097   3.044522  5.634790            0            0
# 0026443     8.042256   5.049856  2.772589            0            0
# 0026444     8.036725   5.056246  2.772589            0            0
# 0026446     8.207276   4.189655  2.772589            0            0
# 0026447     8.042420   5.049856  2.772589            0            0
# 0026470     7.989265   5.049856  2.772589            0            0
# 0026472     8.030618   3.044522  5.616771            0            0
# 0026486     8.049788   5.043425  2.772589            0            0
# 0026495     8.043278   5.049856  2.772589            0            0
# 0026498     8.049788   5.056246  2.772589            0            0
# 0026501     8.049788   5.043425  2.772589            0            0
# 0026504     8.050295   4.304065  3.091042            0            0
# 0026518     8.043278   5.049856  2.772589            0            1
# 0026521     8.059298   4.025352  2.772589            0            0
# 0026522     8.023968   2.890372  5.697093            0            0
# 0026528     8.059302   4.025352  2.772589            0            0
# 0026550     8.049462   5.062595  2.772589            0            0
# 0026551     8.044017   5.049856  3.135494            0            0
# 0026560     8.042095   5.056246  2.772589            0            0
# 0026572     8.728505   5.777652  3.332205            0            0
# 0026576     7.980434   5.111988  2.772589            0            0
# 0026600     8.019656   5.081404  3.610918            0            0
# 0026605     8.059298   3.970292  2.772589            1            0
# 0026606     8.017403   4.262680  2.772589            0            0
# 0026618     8.049781   5.062595  2.772589            0            0
# 0026631     8.049788   5.043425  2.772589            0            0
# 0026632     8.014666   4.770685  4.025352            0            0
# 0026655     8.023972   3.044522  5.666427            0            0
# ...              ...        ...       ...          ...          ...
# 0229094     7.049255   3.912023  2.772589            0            0
# 0229115     7.190676   3.912023  2.772589            0            0
# 0229158     7.049255   3.891820  2.772589            1            0
# 0229184     7.049255   3.891820  2.772589            0            0
# 0229185     7.049255   3.891820  2.772589            0            0
# 0229195     6.985642   3.988984  3.367296            0            0
# 0229197     7.049255   3.912023  2.772589            0            0
# 0229203     7.049255   3.871201  2.772589            0            1
# 0229208     7.049255   3.891820  2.772589            0            0
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest

# %% [markdown]
# ---
# # B. Feature Selection
#
# ## Using Select K-Best to find best features.

# %%
sk_1=SelectKBest(k='all')
sk_1.fit(X=f_tr_sc,y=f_tr_target.values)
i=pd.DataFrame(sk_1.scores_,index=f_tr.columns.tolist(),columns=['Fscore']).sort_values(by=['Fscore'],ascending=False)
index=i.index[:25].tolist()
print (index)
i
# Out:
# [u'MNTOPCODE_DIS', u'MNTOPCODE_CTS', u'CLASCODE_CT', u'MEDIUMCODE_CI', 'Recency', u'MEDIUMCODE_LE', u'CLASCODE_AN', u'CLASCODE_RI', u'CONTDIREC_I', u'CONTDIREC_O', u'MEDIUMCODE_EM', u'MNTOPCODE_TAX', u'MEDIUMCODE_ME', u'CLASCODE_ID', 'Total_Pamt', u'CLASCODE_AK', u'MEDIUMCODE_TE', u'MEDIUMCODE_FF', u'MNTOPCODE_COR', u'MNTOPCODE_FIN', u'MNTOPCODE_ALL', u'MEDIUMCODE_FX', 'Frequency', u'MEDIUMCODE_MR', u'MNTOPCODE_CAN']
#                      Fscore
# MNTOPCODE_DIS  15506.109375
# MNTOPCODE_CTS   2048.758413
# CLASCODE_CT     2032.530862
# MEDIUMCODE_CI   2016.519564
# Recency         1955.533172
# MEDIUMCODE_LE   1231.608672
# CLASCODE_AN     1125.580969
# CLASCODE_RI      905.819445
# CONTDIREC_I      886.230248
# CONTDIREC_O      886.230248
# MEDIUMCODE_EM    327.382657
# MNTOPCODE_TAX    114.171976
# MEDIUMCODE_ME     91.979113
# CLASCODE_ID       73.085755
# Total_Pamt        67.604968
# CLASCODE_AK       57.548863
# MEDIUMCODE_TE     50.950336
# MEDIUMCODE_FF     34.563988
# MNTOPCODE_COR     14.485981
# MNTOPCODE_FIN     13.802239
# MNTOPCODE_ALL      9.442947
# MEDIUMCODE_FX      9.442947
# Frequency          6.778616
# MEDIUMCODE_MR      6.200695
# MNTOPCODE_CAN      3.526229
# MNTOPCODE_IRE      2.462821
# MNTOPCODE_ARR      0.738498
# MEDIUMCODE_CA      0.684797
# MNTOPCODE_REP      0.684797
# MNTOPCODE_VIS      0.547636
# MEDIUMCODE_RM      0.273617
# MNTOPCODE_IFF      0.273617
# MNTOPCODE_PRO      0.216631
# MNTOPCODE_FIC      0.205175
# MNTOPCODE_VOL      0.136758
# MNTOPCODE_INF      0.068367
# MNTOPCODE_ENR      0.068367
# CLASCODE_CM             NaN
# MEDIUMCODE_TM           NaN
# MNTOPCODE_WEB           NaN

# %%
# we will go ahead with first 25 highest score features
sk_f_tr_sc=f_tr_sc_df[index].values

# %% [markdown]
# ## Since there is class imbalance here so we need to resample data and counter this imbalance, using (SMOTE) technique  will help our case.

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
sm_1=SMOTE(random_state=3)
x_tr_sk_resample,y_tr_sk_resample=sm_1.fit_sample(sk_f_tr_sc,f_tr_target.values)

# %%
print "Before REsample {}".format(Counter(f_tr_target.values))
print "resample data {}".format(Counter(y_tr_sk_resample))
# Out:
# Before REsample Counter({0: 5455, 1: 373})
# resample data Counter({0: 5455, 1: 5455})

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import confusion_matrix , classification_report
from sklearn.grid_search import GridSearchCV

# %% [markdown]
# ---
# # C. MODEL BUILDING
#
# ## 1 - LOGISTIC REGRESSION
# - Doing Grid Search to find best value of C

# %%
lr_1=LogisticRegression(random_state=5)
grid={'C': [.001,.01,.1,1]}

# %%
gscv=GridSearchCV(estimator=lr_1,param_grid=grid,cv=5,scoring='recall')
gscv.fit(x_tr_sk_resample,y_tr_sk_resample)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=5, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'C': [0.001, 0.01, 0.1, 1]}, pre_dispatch='2*n_jobs',
#        refit=True, scoring='recall', verbose=0)

# %%
gscv.grid_scores_
# Out:
# [mean: 0.94152, std: 0.00551, params: {'C': 0.001},
#  mean: 0.94372, std: 0.00561, params: {'C': 0.01},
#  mean: 0.95160, std: 0.00612, params: {'C': 0.1},
#  mean: 0.95380, std: 0.00685, params: {'C': 1}]

# %%
gscv.best_estimator_
# Out:
# LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=5, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# ## Best value for C is 1
#
# ---

# %% [markdown]
# ### Evaluating Model's Performance

# %%
round(cross_val_score(estimator=gscv.best_estimator_,X=x_tr_sk_resample,y=y_tr_sk_resample,cv=5,scoring='roc_auc').mean(),2)
# Out:
# 0.99

# %%
confusion_matrix(y_true=y_tr_sk_resample,y_pred=gscv.best_estimator_.predict(x_tr_sk_resample))
# Out:
# array([[5387,   68],
#        [ 252, 5203]])

# %%
print classification_report(y_true=y_tr_sk_resample,y_pred=gscv.best_estimator_.predict(x_tr_sk_resample))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97      5455
#           1       0.99      0.95      0.97      5455
#
# avg / total       0.97      0.97      0.97     10910

# %% [markdown]
# ## Classification report Suggest that our Model is doing well in classifying Both classes
#
# ---

# %%
plt.figure(figsize=(20,10))
ax=pd.Series(gscv.best_estimator_.coef_.ravel()).plot(kind='bar')
ax.set_xticklabels(index);

# %% [markdown]
# ### The above plot shows relative effect of predictors on classifying ` CHURN`
#  ***
# <big>
#
# -  `MNTOPCODE_DIS` is most powerful predictive feature.
# - `Recency` is the 2nd most powerful predictive feature.
# -  Frequency of donating have a positive impact on predicting Churn `frequency`
# -  FF(face to face) meeting is one important factor `MNTOPCODE_CORR`
# -  `Total_Pamt` is also a significant factor in determining churn customers

# %% [markdown]
# # Validating on Validation data

# %%
# Resampling data to tacke class imabalance
x_vl_resample,y_vl_resample=sm_1.fit_sample(f_vl[index],f_v1_target.values)

# %%
print "Before REsample {}".format(Counter(f_v1_target.values))
print "resample data {}".format(Counter(y_vl_resample))
# Out:
# Before REsample Counter({0: 481, 1: 39})
# resample data Counter({0: 481, 1: 481})

# %%
# scaling
x_vl_sc=StandardScaler().fit_transform(x_vl_resample)

# %%
round(cross_val_score(estimator=gscv.best_estimator_,cv=5,X=x_vl_sc,y=y_vl_resample,scoring='roc_auc').mean(),2)
# Out:
# 1.0

# %%
print classification_report(y_pred=gscv.best_estimator_.predict(x_vl_sc),y_true=y_vl_resample)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.71      1.00      0.83       481
#           1       0.99      0.60      0.75       481
#
# avg / total       0.85      0.80      0.79       962

# %%
confusion_matrix(y_pred=gscv.best_estimator_.predict(x_vl_sc),y_true=y_vl_resample)
# Out:
# array([[479,   2],
#        [194, 287]])

# %% [markdown]
# # Test Data

# %%
#Resampling
x_test_resample,y_test_resample=sm_1.fit_sample(f_test[index],f_test_target.values)

# %%
#Scaling 
x_test_sc=StandardScaler().fit_transform(x_test_resample)

# %%
round(cross_val_score(estimator=gscv.best_estimator_,cv=5,X=x_test_sc,y=y_test_resample,scoring='roc_auc').mean(),2)
# Out:
# 1.0

# %%
from sklearn.cross_validation import cross_val_predict
y=cross_val_predict(cv=5,estimator=gscv.best_estimator_,X=x_test_sc,y=y_test_resample)

# %%
confusion_matrix(y_pred=y,y_true=y_test_resample)
# Out:
# array([[456,  13],
#        [ 10, 459]])

# %%
print classification_report(y_pred=y,y_true=y_test_resample)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      0.97      0.98       469
#           1       0.97      0.98      0.98       469
#
# avg / total       0.98      0.98      0.98       938

# %% [markdown]
# # With Logistic Regression:
#
# <big>
# - Train Data Score (ROC_AUC)- 99%
# - Validation Sample Score - 100%
# - Test Sample score- 100%
#
# ***

# %% [markdown]
# ---
#
# # 2nd Model: RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_1=RandomForestClassifier(n_estimators=50,max_depth=10,random_state=5)

# %% [markdown]
# # On validation data

# %%
rf_1.fit(x_vl_sc,y_vl_resample)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=1,
#             oob_score=False, random_state=5, verbose=0, warm_start=False)

# %%
cross_val_score(estimator=rf_1,cv=5,X=x_vl_sc,y=y_vl_resample,scoring='roc_auc')
# Out:
# array([ 0.99936231,  1.        ,  1.        ,  1.        ,  1.        ])

# %%
ypred=cross_val_predict(estimator=rf_1,cv=5,X=x_vl_sc,y=y_vl_resample)

# %%
print " Classification Report \n", classification_report(y_pred=ypred,y_true=y_vl_resample)
print "Confusion Matrix :- \n",confusion_matrix(y_pred=ypred,y_true=y_vl_resample)
# Out:
#  Classification Report
#              precision    recall  f1-score   support
#
#           0       0.99      0.99      0.99       481
#           1       0.99      0.99      0.99       481
#
# avg / total       0.99      0.99      0.99       962
#
# Confusion Matrix :-
# [[476   5]
#  [  3 478]]

# %% [markdown]
# # test data

# %%
cross_val_score(estimator=rf_1,cv=5,X=x_test_sc,y=y_test_resample,scoring='roc_auc')
# Out:
# array([ 0.99303984,  1.        ,  1.        ,  0.9983024 ,  1.        ])

# %%
print "ON TEST DATA :\n"
ypred_test=cross_val_predict(estimator=rf_1,cv=5,X=x_test_sc,y=y_test_resample)
print "Classification Report:-  \n ", classification_report(y_pred=ypred_test,y_true=y_test_resample),'\n'
print "Confusion Matrix :- \n",confusion_matrix(y_pred=ypred_test,y_true=y_test_resample)
# Out:
# ON TEST DATA :
#
# Classification Report:-
#                precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98       469
#           1       0.99      0.98      0.98       469
#
# avg / total       0.98      0.98      0.98       938
#
#
# Confusion Matrix :-
# [[463   6]
#  [  9 460]]

# %%
plt.figure(figsize=(20,10))
ax=pd.Series(rf_1.feature_importances_).plot(kind='bar')
ax.set_xticklabels(index);

# %% [markdown]
# # Random Forest classifier has better performance in terms of Classifying `Churn` customers as expressed in Confusion Matrix
#
# ---
#
# <big>Confusion Matrix- Random Forest Test Data :- </big>
#
#
# |   |Cls-0   | Cls-1 |
# |---|---|--- |---|
# | Cls 0 |  463   |  6  |
# | Cls 1 |  9  |   460 |
#
#
#   ---
#
#
#  <big>                                         Confusion Matrix- Logistic Regression Test Data :-
#
#
#
#    |  | Cls-0 |  Cls-1  |
# |---|---|--- |---|
# | Cls- 0 |  456   |  13 |
# | Cls- 1 |  16 |   453 |
